# %% [markdown]
# <a href="https://colab.research.google.com/github/Arulsha26/real-estate-price-prediction-using-linear-regression/blob/main/real_estate_price_prediction_using_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/real_estate_price_size.csv')

# %%
data.head()
# Out:
#         price     size
# 0  234314.144   643.09
# 1  228581.528   656.22
# 2  281626.336   487.29
# 3  401255.608  1504.75
# 4  458674.256  1275.46

# %%
data.isnull().sum()
# Out:
# price    0
# size     0
# dtype: int64

# %%
x=data[['size']]
y=data[['price']]

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=46)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# [111299.0753184]
# [[214.21915198]]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8039105574166924

# %%
lr.predict([[100],[50]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[132720.99051674],
#        [122010.03291757]])

# %%
plt.scatter(x_train,y_train,color='r')
plt.plot(x_test,y_pred,color='b')

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error

print('Mean Absolute Error:', mean_absolute_error(y_test,y_pred))
print('Mean squared Error:', mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test)))
# Out:
# Mean Absolute Error: 33312.230112946316
# Mean squared Error: 1705398723.8171425
# Root Mean Squared Error: 41296.4735034015
